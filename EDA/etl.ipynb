# %% [markdown]
# # <b>ETL Process</b>
# Use this notebook to complete the ETL Process for each dataset.

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import re
from datetime import datetime
from langdetect import detect
from googletrans import Translator
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import warnings
import logging

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
campaign_performance = pd.read_excel('.././Raw Dataset/US Pathway Complete Data.xlsx', sheet_name='campaign_performance')
leads_generated = pd.read_excel('.././Raw Dataset/US Pathway Complete Data.xlsx', sheet_name='Leads Generated')
phone_metrics = pd.read_excel('.././Raw Dataset/US Pathway Complete Data.xlsx', sheet_name='Phone Metrics')
tokens_paid = pd.read_excel('.././Raw Dataset/US Pathway Complete Data.xlsx', sheet_name='Tokens Paid')
candidate_application_tracker = pd.read_excel('.././Raw Dataset/US Pathway Complete Data.xlsx', sheet_name='Candidate Application Tracker')

# %%
cp = campaign_performance.copy()
lg = leads_generated.copy()
pm = phone_metrics.copy()
tp = tokens_paid.copy()
cat = candidate_application_tracker.copy()

# %% [markdown]
# ### <b>Campaign Peformance</b>

# %% [markdown]
# #### `Cleaning`
# Performing basic operations like :
# - Removing Duplicates
# - Removing Irrelevant Data (URLs, HTML tags)
# - Standardizing Capitalization
# - Converting Data Types (Dates)
# - Clear Formatting (Data Collected from various sources come up with various formats)
# - Fixing Errors (US dollars to Rs.)
# - Language Translation

# %%
def clean_dataframe(df):
    def remove_html_tags(text):
        return re.sub('<.*?>', '', str(text)) if pd.notnull(text) else text

    def standardize_capitalization(text):
        return str(text).lower() if pd.notnull(text) else text

    def convert_date(value):
        if pd.isnull(value):
            return value
        try:
            return pd.to_datetime(value)
        except:
            return value

    def fix_currency(value):
        if pd.isnull(value):
            return value
        if isinstance(value, str) and '$' in value:
            return float(value.replace('$', '')) * 75
        return value

    def safe_strip(x):
        return x.strip() if isinstance(x, str) else x

    df = df.drop_duplicates()

    for column in df.columns:
        if df[column].dtype == 'object':

            df[column] = df[column].apply(lambda x: re.sub(r'http\S+', '', str(x)) if pd.notnull(x) else x)
            df[column] = df[column].apply(remove_html_tags)
            df[column] = df[column].apply(standardize_capitalization)
            df[column] = df[column].apply(fix_currency)

        elif df[column].dtype in ['int64', 'float64']:
            pass

        if df[column].dtype == 'object':
            df[column] = df[column].apply(convert_date)

    df = df.applymap(safe_strip)

    return df

# %%
cp = clean_dataframe(cp)

# %% [markdown]
# `Identifying Missing Values`
#
# There are three types of missing values:
# - MCAR (Missing completely at random)
# - MAR (Missing at random)
# - MNAR (Missing not at random)

# %%
def missing_data(df):
    total = df.isnull().sum().sort_values(ascending = False)
    Percentage = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
    return pd.concat([total, Percentage], axis = 1, keys = ['Total', 'Percentage'])

missing_data(cp)
# Out:
#                      Total  Percentage
# campaign_start_date  24287   85.116002
# adset_name            4247   14.883998
# click_through_rate      37    0.129670
# dates                    0    0.000000
# campaign_name            0    0.000000
# creative_name            0    0.000000
# total_spent              0    0.000000
# impressions              0    0.000000
# clicks                   0    0.000000
# leads                    0    0.000000
# platform                 0    0.000000

# %%
def analyze_missing_data(df, column):
    
    missing_mask = df[column].isnull()
    if not missing_mask.any():
        return "No missing values in this column."
    
    observed = df.loc[:, df.columns != column].groupby(missing_mask).count()
    chi2, p_value, dof, expected = chi2_contingency(observed)
    
    if p_value > 0.05:
        return "MCAR (Missing Completely At Random): The missing data appears to be completely random."
    
    correlations = df.drop(column, axis=1).corrwith(missing_mask)
    if (correlations.abs() > 0.3).any():
        return "MAR (Missing At Random): The missing data appears to be related to other variables."
    
    return "MNAR (Missing Not At Random): The missing data appears to be related to unobserved factors or the missing values themselves."

# %%
def analyze_dataframe(df):
    results = {}
    for column in df.columns:
        results[column] = analyze_missing_data(df, column)
    
    result_df = pd.DataFrame.from_dict(results, orient='index', columns=['Missing Data Analysis'])
    return result_df

# %%
analyze_dataframe(cp)
# Out:
#                                                  Missing Data Analysis
# dates                                No missing values in this column.
# campaign_name                        No missing values in this column.
# campaign_start_date  MNAR (Missing Not At Random): The missing data...
# creative_name                        No missing values in this column.
# total_spent                          No missing values in this column.
# impressions                          No missing values in this column.
# clicks                               No missing values in this column.
# click_through_rate   MCAR (Missing Completely At Random): The missi...
# leads                                No missing values in this column.
# platform                             No missing values in this column.
# adset_name           MNAR (Missing Not At Random): The missing data...

# %%
cp.drop(columns=['campaign_start_date'], inplace=True)

# %%
def impute(df, col):
    df = df.copy()

    le = LabelEncoder()
    df['encoded'] = le.fit_transform(df[col].astype(str))

    imputer = SimpleImputer(strategy='most_frequent')
    df['encoded'] = imputer.fit_transform(df[['encoded']])

    df[col] = le.inverse_transform(df['encoded'])
    df = df.drop('encoded', axis=1)

    return df

cp = impute(cp, 'adset_name')

# %%
cp.dropna(inplace=True)

# %%
cp.head()
# Out:
#        dates                        campaign_name  \
# 0 2024-04-29           usp_search_aptntska_250124
# 1 2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 2 2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 3 2024-05-02  usp_2_lead-gen-2_top4-states_050424
# 4 2024-05-02  usp_2_lead-gen-2_top4-states_050424
#
#                       creative_name  total_spent  impressions  clicks  \
# 0                                --      6766.15         1250     220
# 1  #7 ( graphic ) - get a free pass       946.38         3154       9
# 2          usp_s3_never-been-easier       170.40         2695       8
# 3                usp_s4_do-you-have        55.65          577       2
# 4               usp_s1_we-guarantee       296.94         1466      10
#
#    click_through_rate  leads  platform          adset_name
# 0            0.176000   25.0    google            gmat/gre
# 1            0.285352    1.0  facebook  usp-2_ka_tn_050424
# 2            0.296846    0.0  facebook  usp-2_ka_tn_050424
# 3            0.346620    0.0  facebook  usp-2_ka_tn_050424
# 4            0.682128    1.0  facebook  usp-2_ap_ts_050424

# %%
cp.to_csv("CampaignPerformance.csv", index=False, header=True)

# %%
analyze_dataframe(cp)
# Out:
#                                 Missing Data Analysis
# dates               No missing values in this column.
# campaign_name       No missing values in this column.
# creative_name       No missing values in this column.
# total_spent         No missing values in this column.
# impressions         No missing values in this column.
# clicks              No missing values in this column.
# click_through_rate  No missing values in this column.
# leads               No missing values in this column.
# platform            No missing values in this column.
# adset_name          No missing values in this column.

# %% [markdown]
# ### <b>Leads Generated</b>

# %% [markdown]
# #### `Cleaning`
# Performing basic operations like :
# - Removing Duplicates
# - Removing Irrelevant Data (URLs, HTML tags)
# - Standardizing Capitalization
# - Converting Data Types (Dates)
# - Clear Formatting (Data Collected from various sources come up with various formats)
# - Fixing Errors (US dollars to Rs.)
# - Language Translation

# %%
lg = clean_dataframe(lg)

# %% [markdown]
# `Identifying Missing Values`
#
# There are three types of missing values:
# - MCAR (Missing completely at random)
# - MAR (Missing at random)
# - MNAR (Missing not at random)

# %%
def analyze_dataframe(df):
    results = {}
    for column in df.columns:
        total_missing = df[column].isnull().sum()
        missing_percentage = (total_missing / len(df)) * 100
        missing_type = analyze_missing_data(df, column)
        
        results[column] = {
            'Total Missing': total_missing,
            'Percentage Missing': missing_percentage,
            'Missing Data Type': missing_type
        }
    
    result_df = pd.DataFrame.from_dict(results, orient='index')
    result_df = result_df.sort_values('Percentage Missing', ascending=False)
    
    # Format the percentage column
    result_df['Percentage Missing'] = result_df['Percentage Missing'].apply(lambda x: f"{x:.2f}%")
    
    return result_df

analyze_dataframe(lg)
# Out:
#                        Total Missing Percentage Missing  \
# form_name                       2339              7.14%
# contacted                       1964              5.99%
# lsq_source                       765              2.33%
# mapped                           711              2.17%
# lsq_lead_stage                   672              2.05%
# lsq_lead_owner                   607              1.85%
# Ad Name                           47              0.14%
# Campaign Name                     47              0.14%
# work_experience                    7              0.02%
# graduation_degree                  6              0.02%
# graduation_percentage              5              0.02%
# lead_id                            0              0.00%
# created_time                       0              0.00%
# platform                           0              0.00%
# lead_id.1                          0              0.00%
#
#                                         Missing Data Type
# form_name              Non-numeric column (7.14% missing)
# contacted              Non-numeric column (5.99% missing)
# lsq_source             Non-numeric column (2.33% missing)
# mapped                 Non-numeric column (2.17% missing)
# lsq_lead_stage         Non-numeric column (2.05% missing)
# lsq_lead_owner         Non-numeric column (1.85% missing)
# Ad Name                Non-numeric column (0.14% missing)
# Campaign Name          Non-numeric column (0.14% missing)
# work_experience        Non-numeric column (0.02% missing)
# graduation_degree      Non-numeric column (0.02% missing)
# graduation_percentage                MCAR (0.02% missing)
# lead_id                                 No missing values
# created_time                            No missing values
# platform                                No missing values
# lead_id.1                               No missing values

# %%
def impute_column(df, col):
    
    df_copy = df.copy()

    if pd.api.types.is_numeric_dtype(df_copy[col]):
        imputer = KNNImputer(n_neighbors=5)
        df_copy[col] = imputer.fit_transform(df_copy[[col]])
    else:
        le = LabelEncoder()
        nan_mask = df_copy[col].isna()
        le.fit(df_copy[col].dropna())
        df_copy.loc[~nan_mask, col] = le.transform(df_copy.loc[~nan_mask, col])
        imputer = SimpleImputer(strategy='most_frequent')
        df_copy[col] = imputer.fit_transform(df_copy[[col]])
        df_copy[col] = le.inverse_transform(df_copy[col].astype(int))
    
    return df_copy

# %%
lg = impute_column(lg, 'contacted')
lg = impute_column(lg, 'lsq_source')
lg = impute_column(lg, 'mapped')
lg = impute_column(lg, 'lsq_lead_stage')
lg = impute_column(lg, 'lsq_lead_owner')
lg = impute_column(lg, 'Ad Name')
lg = impute_column(lg, 'Campaign Name')

# %%
lg.dropna(inplace=True)

# %%
lg.to_csv("LeadsGenerated.csv", header=True, index=False)

# %%
analyze_dataframe(lg)
# Out:
#                        Total Missing Percentage Missing  \
# lead_id                            0              0.00%
# created_time                       0              0.00%
# Ad Name                            0              0.00%
# Campaign Name                      0              0.00%
# form_name                          0              0.00%
# platform                           0              0.00%
# lead_id.1                          0              0.00%
# graduation_degree                  0              0.00%
# graduation_percentage              0              0.00%
# work_experience                    0              0.00%
# mapped                             0              0.00%
# contacted                          0              0.00%
# lsq_lead_stage                     0              0.00%
# lsq_lead_owner                     0              0.00%
# lsq_source                         0              0.00%
#
#                                        Missing Data Type
# lead_id                No missing values in this column.
# created_time           No missing values in this column.
# Ad Name                No missing values in this column.
# Campaign Name          No missing values in this column.
# form_name              No missing values in this column.
# platform               No missing values in this column.
# lead_id.1              No missing values in this column.
# graduation_degree      No missing values in this column.
# graduation_percentage  No missing values in this column.
# work_experience        No missing values in this column.
# mapped                 No missing values in this column.
# contacted              No missing values in this column.
# lsq_lead_stage         No missing values in this column.
# lsq_lead_owner         No missing values in this column.
# lsq_source             No missing values in this column.

# %% [markdown]
# ### <b>Phone Metrics</b>

# %% [markdown]
# #### `Cleaning`
# Performing basic operations like :
# - Removing Duplicates
# - Removing Irrelevant Data (URLs, HTML tags)
# - Standardizing Capitalization
# - Converting Data Types (Dates)
# - Clear Formatting (Data Collected from various sources come up with various formats)
# - Fixing Errors (US dollars to Rs.)
# - Language Translation

# %%
def clean_dataframe(df):
    def remove_html_tags(text):
        return re.sub('<.*?>', '', str(text)) if pd.notnull(text) else text

    def standardize_capitalization(text):
        return str(text).lower() if pd.notnull(text) else text

    def convert_date(value):
        if pd.isnull(value):
            return value
        try:
            return pd.to_datetime(value)
        except:
            return value

    def fix_currency(value):
        if pd.isnull(value):
            return value
        if isinstance(value, str) and '$' in value:
            try:
                cleaned_value = re.sub(r'[^\d.]', '', value)
                return float(cleaned_value) * 75
            except ValueError:
                print(f"Warning: Could not convert '{value}' to float in currency conversion.")
                return value
        return value

    def check_currency_column(df, column):
        problematic_values = df[df[column].apply(lambda x: isinstance(x, str) and '$' in x and not re.sub(r'[^\d.]', '', x).replace('.', '').isdigit())]
        if not problematic_values.empty:
            print(f"Problematic values in {column}:")
            print(problematic_values[column].value_counts())
        return problematic_values
    
    def clean_currency_column(df, column):
        problematic_rows = check_currency_column(df, column)
        if not problematic_rows.empty:
            print(f"Dropping {len(problematic_rows)} rows with invalid currency data.")
            df = df.drop(problematic_rows.index)
        return df
    def safe_strip(x):
        return x.strip() if isinstance(x, str) else x

    df = df.drop_duplicates()

    for column in df.columns:
        if df[column].dtype == 'object':
            if '$' in df[column].values:
                initial_rows = len(df)
                df = clean_currency_column(df, column)
                rows_dropped = initial_rows - len(df)
                if rows_dropped > 0:
                    cleaning_log.append(f"Dropped {rows_dropped} rows from {column} due to invalid currency data.")
            
            df[column] = df[column].apply(fix_currency)

            df[column] = df[column].apply(lambda x: re.sub(r'http\S+', '', str(x)) if pd.notnull(x) else x)
            df[column] = df[column].apply(remove_html_tags)
            df[column] = df[column].apply(standardize_capitalization)
# Warning: Could not convert 'lã«o $ã¯?g' to float in currency conversion.
# Warning: Could not convert '$umeet maheshwari' to float in currency conversion.
# Warning: Could not convert '$umeet maheshwari' to float in currency conversion.
# Warning: Could not convert '$_a_n_!_y_a_' to float in currency conversion.
# Warning: Could not convert 'khushi???$hekhawat' to float in currency conversion.
# Warning: Could not convert 'h@$hu' to float in currency conversion.
# Warning: Could not convert 'my(ute$y_$tor!?s' to float in currency conversion.
# Warning: Could not convert 'lã«o $ã¯?g' to float in currency conversion.
# Warning: Could not convert 'j^$$ dhaliw@l' to float in currency conversion.
# Warning: Could not convert 'j^$$ dhaliw@l' to float in currency conversion.
# Warning: Could not convert 'j^$$ dhaliw@l' to float in currency conversion.
# Warning: Could not convert '*keerthy_*kirtu$' to float in currency conversion.
# Warning: Could not convert '*keerthy_*kirtu$' to float in currency conversion.
# Warning: Could not convert '*keerthy_*kirtu$' to float in currency conversion.
# Warning: Could not convert '$_a_n_!_y_a_' to float in currency conversion.
# Warning: Could not convert '$_a_n_!_y_a_' to float in currency conversion.
# Warning: Could not convert 'anno $am rovira' to float in currency conversion.
# Warning: Could not convert '$_a_n_!_y_a_' to float in currency conversion.
# Warning: Could not convert 'h@$hu' to float in currency conversion.
# Warning: Could not convert '$_a_n_!_y_a_' to float in currency conversion.
# Warning: Could not convert '*keerthy_*kirtu$' to float in currency conversion.
# Warning: Could not convert 'my(ute$y_$tor!?s' to float in currency conversion.
# Warning: Could not convert 'sahmika $r!dh@r' to float in currency conversion.
# Warning: Could not convert '?@$#' to float in currency conversion.
# Warning: Could not convert 'lã«o $ã¯?g' to float in currency conversion.
# Warning: Could not convert 'anno $am rovira' to float in currency conversion.
# Warning: Could not convert '*keerthy_*kirtu$' to float in currency conversion.
# Warning: Could not convert '*keerthy_*kirtu$' to float in currency conversion.
# Warning: Could not convert 'anno $am rovira' to float in currency conversion.

# %% [markdown]
# `Identifying Missing Values`
#
# There are three types of missing values:
# - MCAR (Missing completely at random)
# - MAR (Missing at random)
# - MNAR (Missing not at random)

# %%
def analyze_missing_data(df, column):
    missing_mask = df[column].isnull()
    
    if not missing_mask.any():
        return "No missing values"
    
    missing_percentage = (missing_mask.sum() / len(df)) * 100
    
    if df[column].dtype in ['int64', 'float64']:
        try:
            observed = df.drop(column, axis=1).groupby(missing_mask).count()
            if observed.shape[0] > 1:
                chi2, p_value, dof, expected = chi2_contingency(observed)
                
                if p_value > 0.05:
                    return f"MCAR ({missing_percentage:.2f}% missing)"
                
                correlations = df.drop(column, axis=1).corrwith(missing_mask)
                if (correlations.abs() > 0.3).any():
                    return f"MAR ({missing_percentage:.2f}% missing)"
                
                return f"MNAR ({missing_percentage:.2f}% missing)"
            else:
                return f"Unable to determine ({missing_percentage:.2f}% missing)"
        except ValueError as e:
            print(column, f"Error in analysis: {str(e)} ({missing_percentage:.2f}% missing)")
            return f"Error in analysis: {str(e)} ({missing_percentage:.2f}% missing)"
    else:
        return f"Non-numeric column ({missing_percentage:.2f}% missing)"

def analyze_dataframe(df):
    results = {}
    for column in df.columns:
        results[column] = analyze_missing_data(df, column)
    
    result_df = pd.DataFrame.from_dict(results, orient='index', columns=['Missing Data Analysis'])
    return result_df

analysis_result = analyze_dataframe(pm)
print(analysis_result)
# Out:
# inbound_phone_call_counter Error in analysis: The internally computed table of expected frequencies has a zero element at (0, 13). (23.52% missing)
# mobile_number Error in analysis: The internally computed table of expected frequencies has a zero element at (0, 13). (99.57% missing)
# outbound_phone_call_counter Error in analysis: The internally computed table of expected frequencies has a zero element at (0, 13). (14.39% missing)
#                                                           Missing Data Analysis
# lead_number                                                   No missing values
# first_name                                   Non-numeric column (0.05% missing)
# Lead Id                                     Non-numeric column (25.60% missing)
# inbound_phone_call_counter    Error in analysis: The internally computed tab...
# mobile_number                 Error in analysis: The internally computed tab...
# outbound_phone_call_counter   Error in analysis: The internally computed tab...
# lead_stage                                   Non-numeric column (0.08% missing)
# lead_score                                                    No missing values
# owner                                                         No missing values
# activity                                                      No missing values
# date_of_call                                                  No missing values
# status                                                        No missing values
# call_duration_sec                                             No missing values
# calls_done_by                                                 No missing values
# contacted                                 Unable to determine (100.00% missing)
# call_time                                                     No missing values
# calls_done_by2                                                No missing values
# new_followup                                Non-numeric column (98.70% missing)
# sales_squad                                 Non-numeric column (30.87% missing)
# squad_role                                  Non-numeric column (30.87% missing)
# calls_done_by_without_spaces                                  No missing values

# %%
pm.drop(columns=['mobile_number','contacted','new_followup','sales_squad','squad_role'], inplace=True)

# %%
pm3 = pm.copy()

# %%
analysis_result = analyze_dataframe(pm)
print(analysis_result)
# Out:
#                                             Missing Data Analysis
# lead_number                                     No missing values
# first_name                     Non-numeric column (0.05% missing)
# Lead Id                       Non-numeric column (25.60% missing)
# inbound_phone_call_counter                  MNAR (23.52% missing)
# outbound_phone_call_counter                 MNAR (14.39% missing)
# lead_stage                     Non-numeric column (0.08% missing)
# lead_score                                      No missing values
# owner                                           No missing values
# activity                                        No missing values
# date_of_call                                    No missing values
# status                                          No missing values
# call_duration_sec                               No missing values
# calls_done_by                                   No missing values
# call_time                                       No missing values
# calls_done_by2                                  No missing values
# calls_done_by_without_spaces                    No missing values

# %%
pm = impute_column(pm, 'inbound_phone_call_counter')
pm = impute_column(pm, 'outbound_phone_call_counter')

# %%
pm1 = pm.dropna(subset=['Lead Id'])

# %%
pm.drop(columns=['Lead Id'], inplace=True)

# %%
pm1.dropna(inplace=True)
pm.dropna(inplace=True)

# %%
pm.shape
# Out:
# (257470, 15)

# %%
pm1.shape
# Out:
# (191600, 16)

# %%
def clean_name(name):
    if not isinstance(name, str):
        return name

    name = name.lower()
    name = re.sub(r'[^a-z\s\'-]', '', name)
    name = re.sub(r'\s+', ' ', name)
    name = ' '.join(word.capitalize() for word in name.split())
    name = re.sub(r'\bMc(\w)', lambda x: 'Mc' + x.group(1).upper(), name)
    name = name.strip()

    return name

# %%
pm['first_name'] = pm['first_name'].apply(lambda x: clean_name(x))
pm1['first_name'] = pm1['first_name'].apply(lambda x: clean_name(x))

# %%
pm = pm[pm['first_name']!='']
pm1 = pm1[pm1['first_name']!='']

# %%
analyze_dataframe(pm1)
# Out:
#                              Missing Data Analysis
# lead_number                      No missing values
# first_name                       No missing values
# Lead Id                          No missing values
# inbound_phone_call_counter       No missing values
# outbound_phone_call_counter      No missing values
# lead_stage                       No missing values
# lead_score                       No missing values
# owner                            No missing values
# activity                         No missing values
# date_of_call                     No missing values
# status                           No missing values
# call_duration_sec                No missing values
# calls_done_by                    No missing values
# call_time                        No missing values
# calls_done_by2                   No missing values
# calls_done_by_without_spaces     No missing values

# %%
pm.to_csv('PhoneMetricsWithoutLeaveId.csv', header=True, index=False)
pm1.to_csv('PhoneMetricsWithLeaveId.csv', header=True, index=False)

# %% [markdown]
# ### <b>Tokens Paid</b>

# %% [markdown]
# #### `Cleaning`
# Performing basic operations like :
# - Removing Duplicates
# - Removing Irrelevant Data (URLs, HTML tags)
# - Standardizing Capitalization
# - Converting Data Types (Dates)
# - Clear Formatting (Data Collected from various sources come up with various formats)
# - Fixing Errors (US dollars to Rs.)
# - Language Translation

# %%
tp = clean_dataframe(tp)

# %% [markdown]
# `Identifying Missing Values`
#
# There are three types of missing values:
# - MCAR (Missing completely at random)
# - MAR (Missing at random)
# - MNAR (Missing not at random)

# %%
tp.drop(columns=['upload_timestamp'], inplace=True)

# %%
def analyze_missing_data(df, column):
    
    missing_mask = df[column].isnull()
    if not missing_mask.any():
        return "No missing values in this column."
    
    observed = df.loc[:, df.columns != column].groupby(missing_mask).count()
    chi2, p_value, dof, expected = chi2_contingency(observed)
    
    if p_value > 0.05:
        return "MCAR (Missing Completely At Random): The missing data appears to be completely random."
    
    correlations = df.drop(column, axis=1).corrwith(missing_mask)
    if (correlations.abs() > 0.3).any():
        return "MAR (Missing At Random): The missing data appears to be related to other variables."
    
    return "MNAR (Missing Not At Random): The missing data appears to be related to unobserved factors or the missing values themselves."

def analyze_dataframe(df):
    results = {}
    for column in df.columns:
        total_missing = df[column].isnull().sum()
        missing_percentage = (total_missing / len(df)) * 100
        missing_type = analyze_missing_data(df, column)
        
        results[column] = {
            'Total Missing': total_missing,
            'Percentage Missing': missing_percentage,
            'Missing Data Type': missing_type
        }
    
    result_df = pd.DataFrame.from_dict(results, orient='index')
    result_df = result_df.sort_values('Percentage Missing', ascending=False)
    
    # Format the percentage column
    result_df['Percentage Missing'] = result_df['Percentage Missing'].apply(lambda x: f"{x:.2f}%")
    
    return result_df

analyze_dataframe(tp)
# Out:
#               Total Missing Percentage Missing  \
# Lead ID                 146             54.68%
# status                   26              9.74%
# source                    5              1.87%
# counsellor                2              0.75%
# prospect_id               2              0.75%
# created_date              1              0.37%
# Name                      0              0.00%
# paid_date                 0              0.00%
# cohort                    0              0.00%
# agent                     0              0.00%
#
#                                               Missing Data Type
# Lead ID       MCAR (Missing Completely At Random): The missi...
# status        MCAR (Missing Completely At Random): The missi...
# source        MCAR (Missing Completely At Random): The missi...
# counsellor    MCAR (Missing Completely At Random): The missi...
# prospect_id   MCAR (Missing Completely At Random): The missi...
# created_date  MCAR (Missing Completely At Random): The missi...
# Name                          No missing values in this column.
# paid_date                     No missing values in this column.
# cohort                        No missing values in this column.
# agent                         No missing values in this column.

# %%
tp2 = tp.copy()

# %%
tp2.drop(columns=['Lead ID'], inplace=True)

# %%
analyze_dataframe(tp2)
# Out:
#               Total Missing Percentage Missing  \
# status                   26              9.74%
# source                    5              1.87%
# counsellor                2              0.75%
# prospect_id               2              0.75%
# created_date              1              0.37%
# Name                      0              0.00%
# paid_date                 0              0.00%
# cohort                    0              0.00%
# agent                     0              0.00%
#
#                                               Missing Data Type
# status        MCAR (Missing Completely At Random): The missi...
# source        MCAR (Missing Completely At Random): The missi...
# counsellor    MCAR (Missing Completely At Random): The missi...
# prospect_id   MCAR (Missing Completely At Random): The missi...
# created_date  MCAR (Missing Completely At Random): The missi...
# Name                          No missing values in this column.
# paid_date                     No missing values in this column.
# cohort                        No missing values in this column.
# agent                         No missing values in this column.

# %%
tp2['status'] = tp2['status'].fillna("INACTIVE TOKEN")
tp['status'] = tp2['status'].fillna("INACTIVE TOKEN")

# %%
tp2.dropna(inplace=True)
tp.dropna(inplace=True)

# %%
tp2.to_csv("TokensPaidWithoutLeadID.csv", header=True, index=False)
tp.to_csv("TokensPaidWithLeadID.csv", header=True, index=False)

# %% [markdown]
# ### <b>Candidate Application Tracker</b>

# %%
cat = pd.read_csv("../Raw Dataset/CandidateApplicationTracker.csv")

# %%
cat.head(5)
# Out:
#    S. No. Candidate Name     Counselor Name Block Amount Received Date  \
# 0       1         Vikash  Shailendra Singh                       45152
# 1       2        Hariraj  Shailendra Singh                       45188
# 2       3       Thippesh  Shailendra Singh                       45190
# 3       4        Chintan  Shailendra Singh                       45202
# 4       5          Sagar  Shailendra Singh                       45181
#
#       Univ. Pitched Lead Id                Candidate Preferred College #1  \
# 0           Rutgers     NaN                       Rutgers Business School
# 1  Fairfield/DePaul     NaN  DePaul Kellstadt Graduate School of Business
# 2           Rutgers     NaN                       Rutgers Business School
# 3            DePaul     NaN  DePaul Kellstadt Graduate School of Business
# 4           Rutgers     NaN                       Rutgers Business School
#
#   Candidate Preferred College #2 10th Percentage  12th Percentange  \
# 0                           None              NaN              NaN
# 1                           None              NaN              NaN
# 2                           None              NaN              NaN
# 3                           None              NaN              NaN
# 4                           None              NaN              NaN
#
#   UG - CGPA (out of 10)  GPA (Out of 4) PG - CGPA or % Work Exp.  \
# 0                  7.099           2.83            NaN         3
# 1                   7.95           3.18            NaN         1
# 2                   7.87           3.14            NaN         2
# 3                     10              4            NaN         1
# 4                   7.42           2.96            NaN         3
#
#   Highest Education Designation - Company Name   \
# 0               NaN                         NaN
# 1               NaN                         NaN
# 2               NaN                         NaN
# 3               NaN                         NaN
# 4               NaN                         NaN
#
#        Candidate Application Status         Candidate Loan Status  \
# 0  i20 link from University pending  Loan Sanction Letter Pending
# 1     Deposit Paid & IIM/IIT UnPaid               Loan Sanctioned
# 2  i20 link from University pending               Loan Sanctioned
# 3                 Candidate Dropped             Candidate Dropped
# 4     Deposit Paid & IIM/IIT UnPaid               Loan Sanctioned
#
#                       Remarks - General Reason for dropping  \
# 0  NEW i20 to be issued from University                 NaN
# 1  NEW i20 to be issued from University                 NaN
# 2  NEW i20 to be issued from University                 NaN
# 3  NEW i20 to be issued from University                 NaN
# 4  NEW i20 to be issued from University                 NaN
#
#   If dropped, mention stage of the application KYC & Acad Documents Received  \
# 0                                          NaN                          True
# 1                                          NaN                          True
# 2                                          NaN                          True
# 3                                          NaN                          True
# 4                                          NaN                          True
#
#   Tech Exam Scores Coding Test Score English Exam Scores Exam Taking Date  \
# 0               NR                NR                  NR               NR
# 1               NR                NR                  NR               NR
# 2               NR                NR                  NR               NR
# 3               NR                NR                  NR               NR
# 4               NR                NR                  NR               NR
#
#   English Interview Score (15) Tech. interview Score (10) Application Type  \
# 0                           NR                         NR         Deferred
# 1                           NR                         NR         Deferred
# 2                           NR                         NR         Deferred
# 3                           NR                         NR         Deferred
# 4                           NR                         NR         Deferred
#
#    Intake Status                         U1Choice of School #1  \
# 0      Fall 2024                       Rutgers Business School
# 1      Fall 2024  DePaul Kellstadt Graduate School of Business
# 2      Fall 2024                       Rutgers Business School
# 3  Plans Dropped  DePaul Kellstadt Graduate School of Business
# 4      Fall 2024                       Rutgers Business School
#
#                            U1Choice of Program #1 U1Passport #1 U1Resume #1  \
# 0  Master of Information Technology and Analytics         False       False
# 1                        MS in Business Analytics         False       False
# 2  Master of Information Technology and Analytics         False       False
# 3                        MS in Business Analytics         False       False
# 4  Master of Information Technology and Analytics         False       False
#
#   U1Degree #1 U1Transcript #1 U1Application Fee #1 U1LOR #1 U1SOP #1  \
# 0       False           False                 True     True     True
# 1       False           False                 True     True     True
# 2       False           False                 True     True     True
# 3       False           False                 True     True     True
# 4       False           False                 True     True     True
#
#   U1Pending Stage #1 U1Application Status #1  U1Application Initation Date #1  \
# 0          Completed               Submitted                              NaN
# 1          Completed               Submitted                              NaN
# 2          Completed               Submitted                              NaN
# 3          Completed               Submitted                              NaN
# 4          Completed               Submitted                              NaN
#
#    U1App Partially Submitted Date #1 U1Application Submission Date #1  \
# 0                                NaN                            45178
# 1                                NaN                            45195
# 2                                NaN                            45191
# 3                                NaN                            45209
# 4                                NaN                            45191
#
#   U1Offer Letter #1 U1Offer Letter Provision Date #1 U1Deposit #1  \
# 0          Received                            45188         True
# 1          Received                            45204         True
# 2          Received                            45224         True
# 3          Received                            45230         True
# 4          Received                            45224         True
#
#   U1Deposit Date Paid #1 U2Choice of School #2 U2Choice of Program #2  \
# 0                  45201                   NaN                    NaN
# 1                  45208                   NaN                    NaN
# 2                  45226                   NaN                    NaN
# 3                  45236                   NaN                    NaN
# 4                  45225                   NaN                    NaN
#
#   U2Application Fee #2 U2LOR #2 U2SOP #2 U2Pending Stage #2  \
# 0                False    False    False                NaN
# 1                False    False    False                NaN
# 2                False    False    False                NaN
# 3                False    False    False                NaN
# 4                False    False    False                NaN
#
#   U2Application Status #2  U2Application Initation Date #2  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    U2App Partially Submitted Date #2  U2Application Submission Date #2  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
#
#   U2Offer Letter #2 U2Offer Letter Provision Date #2 U2Deposit #2  \
# 0               NaN                              NaN        False
# 1               NaN                              NaN        False
# 2               NaN                              NaN        False
# 3               NaN                              NaN        False
# 4               NaN                              NaN        False
#
#    U2Deposit Date Paid #2 U3Choice of School #3 U3Choice of Program #3  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
#
#   U3Application Fee #3 U3LOR #3 U3SOP #3 U3Pending Stage #3  \
# 0                False    False    False                NaN
# 1                False    False    False                NaN
# 2                False    False    False                NaN
# 3                False    False    False                NaN
# 4                False    False    False                NaN
#
#   U3Application Status #3  U3Application Initation Date #3  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    U3App Partially Submitted Date #3 U3Application Submission Date #3  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#   U3Offer Letter #3 U3Offer Letter Provision Date #3 U3Deposit #3  \
# 0               NaN                              NaN        False
# 1               NaN                              NaN        False
# 2               NaN                              NaN        False
# 3               NaN                              NaN        False
# 4               NaN                              NaN        False
#
#    U3Deposit Date Paid #3  U3Remarks #3 (If Rejected) U4Choice of School #4  \
# 0                     NaN                         NaN                   NaN
# 1                     NaN                         NaN                   NaN
# 2                     NaN                         NaN                   NaN
# 3                     NaN                         NaN                   NaN
# 4                     NaN                         NaN                   NaN
#
#   U4Choice of Program #4 U4Application Fee #4 U4LOR #4 U4SOP #4  \
# 0                    NaN                False    False    False
# 1                    NaN                False    False    False
# 2                    NaN                False    False    False
# 3                    NaN                False    False    False
# 4                    NaN                False    False    False
#
#                    U4Pending Stage #4 U4Application Status #4  \
# 0  Application Fee #1, LOR #1, SOP #1                     NaN
# 1  Application Fee #1, LOR #1, SOP #1                     NaN
# 2  Application Fee #1, LOR #1, SOP #1                     NaN
# 3  Application Fee #1, LOR #1, SOP #1                     NaN
# 4  Application Fee #1, LOR #1, SOP #1                     NaN
#
#    U4Application Initation Date #4  U4App Partially Submitted Date #4  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    U4Application Submission Date #4 U4Offer Letter #4  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
#
#    U4Offer Letter Provision Date #4 U4Deposit #4  U4Deposit Date Paid #4  \
# 0                               NaN          NaN                     NaN
# 1                               NaN          NaN                     NaN
# 2                               NaN          NaN                     NaN
# 3                               NaN          NaN                     NaN
# 4                               NaN          NaN                     NaN
#
#    U4Remarks #4 (If Rejected) IIM / IIT  Status                 Loan Status  \
# 0                         NaN              Paid  Loan Sanctioned- Futurense
# 1                         NaN            Unpaid  Loan Sanctioned- Futurense
# 2                         NaN              Paid       Loan Sanctioned- Self
# 3                         NaN              Paid  Loan Sanctioned- Futurense
# 4                         NaN              Paid  Loan Sanctioned- Futurense
#
#   Loan Partner I Loan Partner II Loan Application Submit Date Existing Loan  \
# 0   HDFC Credila          MPower                          NaN           NaN
# 1   HDFC Credila             NaN                          NaN           NaN
# 2     Union Bank             NaN                          NaN           NaN
# 3            SBI    HDFC Credila                          NaN           NaN
# 4   HDFC Credila             NaN                        45211           NaN
#
#   CIBIL SCORE No. of defaults Aadhar Card PAN Card Passport CV/Resume  \
# 0         NaN             NaN        True     True     True      True
# 1         NaN             NaN        True     True     True      True
# 2         NaN             NaN        True     True     True      True
# 3         NaN             NaN        True     True     True      True
# 4         NaN             NaN        True     True     True      True
#
#   CIBIL Score Bank Statement (Savings - 6mo) Affidavit Letter  \
# 0       False                          False             True
# 1        True                          False             True
# 2       False                          False             True
# 3       False                          False             True
# 4       False                          False             True
#
#   Sponsorship Letter Offer Letter  Offer Letter Submission Date  \
# 0              False        False                           NaN
# 1              False        False                           NaN
# 2              False        False                           NaN
# 3              False        False                           NaN
# 4              False        False                       45224.0
#
#   i20 Financials Submission i20 Financials Submission Date i20 Provisioned  \
# 0                      True                            NaN        Received
# 1                     False                            NaN             NaN
# 2                      True                     20/02/2024        Received
# 3                      True                            NaN        Received
# 4                      True                     18/02/2024        Received
#
#   i20 Provisioned Date                           Remarks  \
# 0           14/03/2024                               NaN
# 1                  NaN     On Hold due to CX In Hospital
# 2           20/02/2024                               NaN
# 3           28/03/2024  was On Hold due to family issues
# 4           21/02/2024                               NaN
#
#                 Status   SOP Status
# 0            Defer Fall         NaN
# 1            Defer Fall         NaN
# 2            Defer Fall         NaN
# 3  Defer Fall (Dropped)         NaN
# 4            Defer Fall         NaN

# %% [markdown]
# #### `Cleaning`
# Performing basic operations like :
# - Removing Duplicates
# - Removing Irrelevant Data (URLs, HTML tags)
# - Standardizing Capitalization
# - Converting Data Types (Dates)
# - Clear Formatting (Data Collected from various sources come up with various formats)
# - Fixing Errors (US dollars to Rs.)
# - Language Translation

# %%
cat = clean_dataframe(cat)

# %% [markdown]
# `Identifying Missing Values`
#
# There are three types of missing values:
# - MCAR (Missing completely at random)
# - MAR (Missing at random)
# - MNAR (Missing not at random)

# %%
cat.head()
# Out:
#    S. No. Candidate Name    Counselor Name Block Amount Received Date  \
# 0       1         vikash  shailendra singh                      45152
# 1       2        hariraj  shailendra singh                      45188
# 2       3       thippesh  shailendra singh                      45190
# 3       4        chintan  shailendra singh                      45202
# 4       5          sagar  shailendra singh                      45181
#
#       Univ. Pitched Lead Id                Candidate Preferred College #1  \
# 0           rutgers     NaN                       rutgers business school
# 1  fairfield/depaul     NaN  depaul kellstadt graduate school of business
# 2           rutgers     NaN                       rutgers business school
# 3            depaul     NaN  depaul kellstadt graduate school of business
# 4           rutgers     NaN                       rutgers business school
#
#   Candidate Preferred College #2 10th Percentage  12th Percentange  \
# 0                           none              NaN              NaN
# 1                           none              NaN              NaN
# 2                           none              NaN              NaN
# 3                           none              NaN              NaN
# 4                           none              NaN              NaN
#
#   UG - CGPA (out of 10)  GPA (Out of 4) PG - CGPA or % Work Exp.  \
# 0                  7.099           2.83            NaN         3
# 1                   7.95           3.18            NaN         1
# 2                   7.87           3.14            NaN         2
# 3                     10              4            NaN         1
# 4                   7.42           2.96            NaN         3
#
#   Highest Education Designation - Company Name   \
# 0               NaN                         NaN
# 1               NaN                         NaN
# 2               NaN                         NaN
# 3               NaN                         NaN
# 4               NaN                         NaN
#
#        Candidate Application Status         Candidate Loan Status  \
# 0  i20 link from university pending  loan sanction letter pending
# 1     deposit paid & iim/iit unpaid               loan sanctioned
# 2  i20 link from university pending               loan sanctioned
# 3                 candidate dropped             candidate dropped
# 4     deposit paid & iim/iit unpaid               loan sanctioned
#
#                       Remarks - General Reason for dropping  \
# 0  new i20 to be issued from university                 NaN
# 1  new i20 to be issued from university                 NaN
# 2  new i20 to be issued from university                 NaN
# 3  new i20 to be issued from university                 NaN
# 4  new i20 to be issued from university                 NaN
#
#   If dropped, mention stage of the application KYC & Acad Documents Received  \
# 0                                          NaN                          true
# 1                                          NaN                          true
# 2                                          NaN                          true
# 3                                          NaN                          true
# 4                                          NaN                          true
#
#   Tech Exam Scores Coding Test Score English Exam Scores Exam Taking Date  \
# 0               nr                nr                  nr               nr
# 1               nr                nr                  nr               nr
# 2               nr                nr                  nr               nr
# 3               nr                nr                  nr               nr
# 4               nr                nr                  nr               nr
#
#   English Interview Score (15) Tech. interview Score (10) Application Type  \
# 0                           nr                         nr         deferred
# 1                           nr                         nr         deferred
# 2                           nr                         nr         deferred
# 3                           nr                         nr         deferred
# 4                           nr                         nr         deferred
#
#    Intake Status                         U1Choice of School #1  \
# 0      fall 2024                       rutgers business school
# 1      fall 2024  depaul kellstadt graduate school of business
# 2      fall 2024                       rutgers business school
# 3  plans dropped  depaul kellstadt graduate school of business
# 4      fall 2024                       rutgers business school
#
#                            U1Choice of Program #1 U1Passport #1 U1Resume #1  \
# 0  master of information technology and analytics         false       false
# 1                        ms in business analytics         false       false
# 2  master of information technology and analytics         false       false
# 3                        ms in business analytics         false       false
# 4  master of information technology and analytics         false       false
#
#   U1Degree #1 U1Transcript #1 U1Application Fee #1 U1LOR #1 U1SOP #1  \
# 0       false           false                 true     true     true
# 1       false           false                 true     true     true
# 2       false           false                 true     true     true
# 3       false           false                 true     true     true
# 4       false           false                 true     true     true
#
#   U1Pending Stage #1 U1Application Status #1  U1Application Initation Date #1  \
# 0          completed               submitted                              NaN
# 1          completed               submitted                              NaN
# 2          completed               submitted                              NaN
# 3          completed               submitted                              NaN
# 4          completed               submitted                              NaN
#
#    U1App Partially Submitted Date #1 U1Application Submission Date #1  \
# 0                                NaN                            45178
# 1                                NaN                            45195
# 2                                NaN                            45191
# 3                                NaN                            45209
# 4                                NaN                            45191
#
#   U1Offer Letter #1 U1Offer Letter Provision Date #1 U1Deposit #1  \
# 0          received                            45188         true
# 1          received                            45204         true
# 2          received                            45224         true
# 3          received                            45230         true
# 4          received                            45224         true
#
#   U1Deposit Date Paid #1 U2Choice of School #2 U2Choice of Program #2  \
# 0                  45201                   NaN                    NaN
# 1                  45208                   NaN                    NaN
# 2                  45226                   NaN                    NaN
# 3                  45236                   NaN                    NaN
# 4                  45225                   NaN                    NaN
#
#   U2Application Fee #2 U2LOR #2 U2SOP #2 U2Pending Stage #2  \
# 0                false    false    false                NaN
# 1                false    false    false                NaN
# 2                false    false    false                NaN
# 3                false    false    false                NaN
# 4                false    false    false                NaN
#
#   U2Application Status #2  U2Application Initation Date #2  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    U2App Partially Submitted Date #2  U2Application Submission Date #2  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
#
#   U2Offer Letter #2 U2Offer Letter Provision Date #2 U2Deposit #2  \
# 0               NaN                              NaN        false
# 1               NaN                              NaN        false
# 2               NaN                              NaN        false
# 3               NaN                              NaN        false
# 4               NaN                              NaN        false
#
#    U2Deposit Date Paid #2 U3Choice of School #3 U3Choice of Program #3  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
#
#   U3Application Fee #3 U3LOR #3 U3SOP #3 U3Pending Stage #3  \
# 0                false    false    false                NaN
# 1                false    false    false                NaN
# 2                false    false    false                NaN
# 3                false    false    false                NaN
# 4                false    false    false                NaN
#
#   U3Application Status #3  U3Application Initation Date #3  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
#
#    U3App Partially Submitted Date #3 U3Application Submission Date #3  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#   U3Offer Letter #3 U3Offer Letter Provision Date #3 U3Deposit #3  \
# 0               NaN                              NaN        false
# 1               NaN                              NaN        false
# 2               NaN                              NaN        false
# 3               NaN                              NaN        false
# 4               NaN                              NaN        false
#
#    U3Deposit Date Paid #3  U3Remarks #3 (If Rejected) U4Choice of School #4  \
# 0                     NaN                         NaN                   NaN
# 1                     NaN                         NaN                   NaN
# 2                     NaN                         NaN                   NaN
# 3                     NaN                         NaN                   NaN
# 4                     NaN                         NaN                   NaN
#
#   U4Choice of Program #4 U4Application Fee #4 U4LOR #4 U4SOP #4  \
# 0                    NaN                false    false    false
# 1                    NaN                false    false    false
# 2                    NaN                false    false    false
# 3                    NaN                false    false    false
# 4                    NaN                false    false    false
#
#                    U4Pending Stage #4 U4Application Status #4  \
# 0  application fee #1, lor #1, sop #1                     NaN
# 1  application fee #1, lor #1, sop #1                     NaN
# 2  application fee #1, lor #1, sop #1                     NaN
# 3  application fee #1, lor #1, sop #1                     NaN
# 4  application fee #1, lor #1, sop #1                     NaN
#
#    U4Application Initation Date #4  U4App Partially Submitted Date #4  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    U4Application Submission Date #4 U4Offer Letter #4  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
#
#    U4Offer Letter Provision Date #4 U4Deposit #4  U4Deposit Date Paid #4  \
# 0                               NaN          NaN                     NaN
# 1                               NaN          NaN                     NaN
# 2                               NaN          NaN                     NaN
# 3                               NaN          NaN                     NaN
# 4                               NaN          NaN                     NaN
#
#    U4Remarks #4 (If Rejected) IIM / IIT  Status                 Loan Status  \
# 0                         NaN              paid  loan sanctioned- futurense
# 1                         NaN            unpaid  loan sanctioned- futurense
# 2                         NaN              paid       loan sanctioned- self
# 3                         NaN              paid  loan sanctioned- futurense
# 4                         NaN              paid  loan sanctioned- futurense
#
#   Loan Partner I Loan Partner II Loan Application Submit Date Existing Loan  \
# 0   hdfc credila          mpower                          NaN           NaN
# 1   hdfc credila             NaN                          NaN           NaN
# 2     union bank             NaN                          NaN           NaN
# 3            sbi    hdfc credila                          NaN           NaN
# 4   hdfc credila             NaN                        45211           NaN
#
#   CIBIL SCORE No. of defaults Aadhar Card PAN Card Passport CV/Resume  \
# 0         NaN             NaN        true     true     true      true
# 1         NaN             NaN        true     true     true      true
# 2         NaN             NaN        true     true     true      true
# 3         NaN             NaN        true     true     true      true
# 4         NaN             NaN        true     true     true      true
#
#   CIBIL Score Bank Statement (Savings - 6mo) Affidavit Letter  \
# 0       false                          false             true
# 1        true                          false             true
# 2       false                          false             true
# 3       false                          false             true
# 4       false                          false             true
#
#   Sponsorship Letter Offer Letter  Offer Letter Submission Date  \
# 0              false        false                           NaN
# 1              false        false                           NaN
# 2              false        false                           NaN
# 3              false        false                           NaN
# 4              false        false                       45224.0
#
#   i20 Financials Submission i20 Financials Submission Date i20 Provisioned  \
# 0                      true                            NaT        received
# 1                     false                            NaT             NaN
# 2                      true                     2024-02-20        received
# 3                      true                            NaT        received
# 4                      true                     2024-02-18        received
#
#   i20 Provisioned Date                           Remarks  \
# 0  2024-03-14 00:00:00                               NaN
# 1                  NaN     on hold due to cx in hospital
# 2  2024-02-20 00:00:00                               NaN
# 3  2024-03-28 00:00:00  was on hold due to family issues
# 4  2024-02-21 00:00:00                               NaN
#
#                 Status   SOP Status
# 0            defer fall         NaN
# 1            defer fall         NaN
# 2            defer fall         NaN
# 3  defer fall (dropped)         NaN
# 4            defer fall         NaN

# %% [markdown]
# `SOP Status` : Statement of Purpose
#
# `No of defaults` : Only one out of 317 rows has a 5+ defaults, potentially an outlier
#
# `U4 Columns` : Potential outliers

# %%
cat.drop(columns=['U4Choice of School #4', 'U4Choice of Program #4', 'U4Application Fee #4', 'U4LOR #4', 'U4SOP #4', 'U4Pending Stage #4', 'U4Application Status #4', 'U4Application Initation Date #4', 'U4App Partially Submitted Date #4', 'U4Application Submission Date #4', 'U4Offer Letter #4', 'U4Offer Letter Provision Date #4', 'U4Deposit #4', 'U4Deposit Date Paid #4', 'U4Remarks #4 (If Rejected)'], inplace=True)

# %%
cols = ['No. of defaults','Offer Letter Submission Date','i20 Financials Submission Date', 'Remarks','Loan Application Submit Date','If dropped, mention stage of the application','i20 Provisioned Date','Remarks - General']

cat.drop(columns=cols, inplace=True)

# %%
cols = [
    'SOP Status', 'Reason for dropping', 'U3Deposit Date Paid #3', 'U2Deposit Date Paid #2', 'U1Deposit Date Paid #1', 'U3App Partially Submitted Date #3', 'U2App Partially Submitted Date #2', 'U1App Partially Submitted Date #1', 'Loan Partner II', 'U3Offer Letter Provision Date #3', 'U2Deposit Date Paid #2', 'U3Application Submission Date #3', 'U3Application Initation Date #3', 'U1Deposit Date Paid #1', 'U2Application Initation Date #2', 'U2Application Submission Date #2', 'U1Application Initation Date #1', 'U1Application Submission Date #1'
]

cols  = list(set(cols))

# %%
cat.drop(columns=cols, inplace=True)

# %%
cols = ['U3Remarks #3 (If Rejected)','U3Deposit #3','U2Offer Letter Provision Date #2','U1Offer Letter Provision Date #1','Exam Taking Date','CIBIL SCORE','i20 Financials Submission','Offer Letter','Aadhar Card','Bank Statement (Savings - 6mo)','CIBIL Score','PAN Card','Passport','Affidavit Letter','U3Application Fee #3']

cat.drop(columns=cols, inplace=True)

# %%
cat['Existing Loan'].fillna(0, inplace=True)
cat['Loan Partner I'].fillna("Nil",inplace=True)
cat['U3Offer Letter #3'].fillna("Awaited",inplace=True)
cat['U3Choice of School #3'].fillna("No Choice",inplace=True)
cat['U3Choice of Program #3'].fillna("No Choice",inplace=True)
cat['U3Application Status #3'].fillna("Not Submitted",inplace=True)
cat['i20 Provisioned'].fillna("Not Received",inplace=True)
cat['PG - CGPA or %'].fillna(0,inplace=True)
cat['English Interview Score (15)'].fillna(0,inplace=True)
cat['Tech. interview Score (10)'].fillna(0,inplace=True)
cat['Designation - Company Name '].fillna("No company",inplace=True)
cat['12th Percentange'].fillna(0,inplace=True)
cat['10th Percentage '].fillna(0,inplace=True)
cat['U2Offer Letter #2'].fillna("Awaited",inplace=True)
cat['Highest Education'].fillna("No Higher Education",inplace=True)
cat['English Exam Scores'].fillna(0,inplace=True)
cat['Coding Test Score'].fillna(0,inplace=True)
cat['Tech Exam Scores'].fillna(0,inplace=True)
cat['U2Application Status #2'].fillna("Not Submitted",inplace=True)
cat['U2Choice of Program #2'].fillna("No Choice",inplace=True)
cat['U2Choice of School #2'].fillna("No choice",inplace=True)
cat['U1Offer Letter #1'].fillna("Not Received",inplace=True)
cat['Univ. Pitched'].fillna("Not Pitched",inplace=True)
cat['Candidate Preferred College #2'].fillna("No Preference",inplace=True)
cat['Application Type'].fillna('New',inplace=True)
cat['U1Application Status #1'].fillna("Not Submitted",inplace=True)
cat['U1Choice of School #1'].fillna("No Choice",inplace=True)
cat['U1Choice of Program #1'].fillna("No Choice",inplace=True)
cat['Work Exp.'].fillna(0,inplace=True)
cat['CV/Resume'].fillna(cat['CV/Resume'].mode(),inplace=True)
cat['Sponsorship Letter'].fillna(cat['Sponsorship Letter'].mode(), inplace=True)

# %%
cat['CV/Resume'].fillna(cat['CV/Resume'].mode(),inplace=True)
cat['Sponsorship Letter'].fillna(cat['Sponsorship Letter'].mode(),inplace=True)
cat['Candidate Preferred College #1'].fillna('No Preference',inplace=True)
cat['U1Deposit #1'].fillna(cat['U1Deposit #1'].mode(), inplace=True)

# %%
cols =['U3SOP #3','U3LOR #3','U3Pending Stage #3','U1Deposit #1']

cat.drop(columns=cols, inplace=True)

# %%
cols = ['U2LOR #2','U2SOP #2','U1LOR #1','U1SOP #1','U2Pending Stage #2','U1Pending Stage #1','U2Pending Stage #2','U2Application Fee #2','U1Application Fee #1','U1Pending Stage #1']

cat.drop(columns=cols, inplace=True)

# %%
def missing_data(df):
    total = df.isnull().sum().sort_values(ascending = False)
    Percentage = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
    return pd.concat([total, Percentage], axis = 1, keys = ['Total', 'Percentage'])

missing_data(cat)
# Out:
#                                 Total  Percentage
# Lead Id                           186   59.047619
# GPA (Out of 4)                     35   11.111111
# UG - CGPA (out of 10)              34   10.793651
# Sponsorship Letter                 30    9.523810
# CV/Resume                          30    9.523810
# U2Deposit #2                       12    3.809524
# U1Passport #1                       5    1.587302
# U1Resume #1                         5    1.587302
# U1Transcript #1                     5    1.587302
# U1Degree #1                         5    1.587302
# KYC & Acad Documents Received       3    0.952381
# Block Amount Received Date          2    0.634921
# U1Application Status #1             0    0.000000
# U2Choice of School #2               0    0.000000
# U2Choice of Program #2              0    0.000000
# U2Application Status #2             0    0.000000
# U2Offer Letter #2                   0    0.000000
# U1Offer Letter #1                   0    0.000000
# S. No.                              0    0.000000
# U3Choice of School #3               0    0.000000
# U3Choice of Program #3              0    0.000000
# U3Offer Letter #3                   0    0.000000
# IIM / IIT  Status                   0    0.000000
#  Loan Status                        0    0.000000
# Loan Partner I                      0    0.000000
# Existing Loan                       0    0.000000
# i20 Provisioned                     0    0.000000
# U3Application Status #3             0    0.000000
# Intake Status                       0    0.000000
# U1Choice of Program #1              0    0.000000
# U1Choice of School #1               0    0.000000
# Counselor Name                      0    0.000000
# Univ. Pitched                       0    0.000000
# Candidate Preferred College #1      0    0.000000
# Candidate Preferred College #2      0    0.000000
# 10th Percentage                     0    0.000000
# 12th Percentange                    0    0.000000
# PG - CGPA or %                      0    0.000000
# Work Exp.                           0    0.000000
# Highest Education                   0    0.000000
# Designation - Company Name          0    0.000000
# Candidate Application Status        0    0.000000
# Candidate Loan Status               0    0.000000
# Tech Exam Scores                    0    0.000000
# Coding Test Score                   0    0.000000
# English Exam Scores                 0    0.000000
# English Interview Score (15)        0    0.000000
# Tech. interview Score (10)          0    0.000000
# Application Type                    0    0.000000
# Candidate Name                      0    0.000000
# Status                              0    0.000000

# %%
cat2 = cat.dropna(subset=['Lead Id'])
cat.drop(columns=['Lead Id'], inplace=True)

# %%
for column in cat.columns:
    mode_value = cat[column].mode()[0]
    cat[column].fillna(mode_value, inplace=True)

# %%
cat.shape
# Out:
# (315, 50)

# %%
for column in cat2.columns:
    mode_value = cat2[column].mode()[0]
    cat2[column].fillna(mode_value, inplace=True)

# %%
cat.to_csv("CandidateApplicationTrackerWithoutLeadIDs.csv", header=True, index=False)
cat2.to_csv("CandidateApplicationTrackerWithLeadIDs.csv", header=True, index=False)
